# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
from rubin_sim.scheduler.modelObservatory import Model_observatory
from astropy.time import Time

# %%
mo = Model_observatory()

# %%
conditions = mo.return_conditions()

# %%
dir(conditions)
# Out:
# ['FWHMeff',
#  'HA',
#  'M5Depth',
#  '_FWHMeff',
#  '_HA',
#  '_M5Depth',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_airmass',
#  '_alt',
#  '_az',
#  '_az_to_antisun',
#  '_az_to_sun',
#  '_cloud_map',
#  '_lmst',
#  '_mjd',
#  '_pa',
#  '_repr_markdown_',
#  '_season',
#  '_skybrightness',
#  '_slewtime',
#  '_solar_elongation',
#  'airmass',
#  'alt',
#  'az',
#  'az_to_antisun',
#  'az_to_sun',
#  'bulk_cloud',
#  'calc_HA',
#  'calc_M5Depth',
#  'calc_altAz',
#  'calc_az_to_antisun',
#  'calc_az_to_sun',
#  'calc_pa',
#  'calc_solar_elongation',
#  'cloud_map',
#  'clouds',
#  'cumulative_azimuth_rad',
#  'current_filter',
#  'dec',
#  'exptime',
#  'lmst',
#  'mjd',
#  'mjd_start',
#  'moonAlt',
#  'moonAz',
#  'moonDec',
#  'moonPhase',
#  'moonRA',
#  'moonrise',
#  'moonset',
#  'mounted_filters',
#  'nan_map',
#  'night',
#  'nside',
#  'pa',
#  'planet_positions',
#  'queue',
#  'ra',
#  'rotTelPos',
#  'scheduled_observations',
#  'season',
#  'season_floor',
#  'season_length',
#  'season_max_season',
#  'season_modulo',
#  'season_offset',
#  'site',
#  'skybrightness',
#  'slewtime',
#  'solar_elongation',
#  'sunAlt',
#  'sunAz',
#  'sunDec',
#  'sunRA',
#  'sun_RA_start',
#  'sun_n12_rising',
#  'sun_n12_setting',
#  'sun_n18_rising',
#  'sun_n18_setting',
#  'sunrise',
#  'sunset',
#  'targets_of_opportunity',
#  'telAlt',
#  'telAz',
#  'telDec',
#  'telRA',
#  'wind_direction',
#  'wind_speed',
#  'zeros_map']

# %%
hp.mollview(conditions.slewtime, unit='seconds', title='Slewtime', min=5, max=156)
plt.savefig('cond_slewtime.pdf')

# %%
hp.mollview(conditions.skybrightness['r'], unit='$r$ mag arcsec$^{-2}$', title='Sky Brightness',
           max=21.3, min=19.8)
plt.savefig('cond_skybright.pdf')

# %%
hp.mollview(conditions.airmass, unit='(unitless)', title='Airmass', max=3, min=1)
plt.savefig('cond_airmass.pdf')

# %%
hp.mollview(conditions.FWHMeff['r'], unit='arcsec', title='Effective Seeing, $r$', max=2, min=0.73)

# %%
hp.mollview(np.degrees(conditions.solar_elongation), unit='degrees', title='Solar Elongation', max=180, min=0)

# %%
t = Time(conditions.mjd, format='mjd')

# %%
t.isot
# Out:
# '2023-10-01T00:00:00.000'

# %%
np.degrees(conditions.sunAlt)
# Out:
# -17.079943895582822
